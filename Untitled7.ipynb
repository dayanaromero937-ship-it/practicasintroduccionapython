# %% [markdown]
# 1. Escribe un programa que calcule la suma de todos los elementos de una lista dada. La lista sólo puede contener elementos numéricos.

# %%
lista = [15, 25, 10, 50]
suma = 0
for numero in lista:
    suma += numero
print(suma)
# Out:
# 100

# %% [markdown]
# 2. Dada una lista con elementos duplicados, escribir un programa que muestre una nueva lista con el mismo contenido que la primera pero sin elementos duplicados. Para este ejercicio, no puedes hacer uso de objetos de tipo ‘Set’.
# Python

# %%
Lista con duplicados = [1, 2, 2, 3, 4, 4, 4, 5, 1]
lista = []
for elemento in lista duplicados:
    if elemento not in lista:
        lista.append(elemento)
print(*lista)
# Out:
#   Cell In[11], line 1
#     Lista con duplicados = [1, 2, 2, 3, 4, 4, 4, 5, 1]
#           ^
# SyntaxError: invalid syntax

# %%
lista [1,3,4]
suma=0
for numero in lista

# %%
lista = [15, 25, 10, 50]
suma = 0
for numero in lista:
    suma += numero
print(suma)
# Out:
# 100

# %%
"Lista_duplicados" = [1, 2, 2, 3, 4, 4, 4, 5, 1]
lista = []
for elemento in lista_duplicados:
    if elemento not in lista:
        lista.append(elemento)
print(*lista)
# Out:
#   Cell In[16], line 1
#     "Lista_duplicados" = [1, 2, 2, 3, 4, 4, 4, 5, 1]
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
