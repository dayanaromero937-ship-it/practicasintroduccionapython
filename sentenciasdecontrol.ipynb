# %%
a=0
b=7
suma=a+b
print(suma)
# Out:
# 7

# %% [markdown]
# crear un programa en python donde se ingrese por teclado un numero y lo imprime en pantalla

# %%
numero= int(input("ingrese un numero"))
print(numero)
# Out:
# ingrese un numero 7
# 7

# %% [markdown]
# https://github.com/dayanaromero937-ship-it/practicasintroduccionapython/blob/main/examen.ipynb
