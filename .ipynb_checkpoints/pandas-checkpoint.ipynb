# %% [markdown]
# ![image.png](attachment:c4584942-0a46-444a-b88d-5643bbefa2a3.png)

# %% [markdown]
# ## 01MIAR - Estructuras de datos, +Pandas

# %% [markdown]
# ##### Dayana romero

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# ### Operaciones en pandas

# %% [markdown]
# **Búsqueda**

# %%
rand_matrix = np.random.randint(6,size=(2,3))
frame = pd.DataFrame(rand_matrix , columns=list('ABC'))
display(frame)
# Out:
#    A  B  C
# 0  0  0  3
# 1  1  0  3

# %%
# buscando columnas (DataFrame como dic, busca en claves)
'A' in frame
# Out:
# True

# %%
# buscando valores
display(frame.isin([3,2])) # --> mask de respuesta (valores que son 3 o 2)
# Out:
#        A      B     C
# 0  False  False  True
# 1  False  False  True

# %%
# Contar el número de ocurrencias
print(frame.isin([4]).values.sum())
display(frame.isin([4])) #devuelve una mask con valores true si el elemento es 4
print(frame.isin([4]).values)
type(frame.isin([4]).values) # pandas es una capa alrededor de numpy
# Out:
# 0
#        A      B      C
# 0  False  False  False
# 1  False  False  False
# [[False False False]
#  [False False False]]
# numpy.ndarray

# %%
# Cuántos valores son >= 2
mask = frame >= 2
print(mask.values.sum())
display(mask)
# Out:
# 2
#        A      B     C
# 0  False  False  True
# 1  False  False  True

# %% [markdown]
# **Ordenación**

# %%
from random import shuffle
rand_matrix = np.random.randint(20,size=(5,4))
indices = list(range(5))
shuffle(indices) # mezcla indices
frame = pd.DataFrame(rand_matrix , columns=list('DACB'), index=indices)
display(frame)
# Out:
#     D   A   C   B
# 3  19   9   5  16
# 2   6  13   0  19
# 4   5  17  16  11
# 1  19  13   2   2
# 0   7   7  18   5

# %%
# ordenar por índice
display(frame.sort_index(ascending=False))
display(frame)
# Out:
#     D   A   C   B
# 4   5  17  16  11
# 3  19   9   5  16
# 2   6  13   0  19
# 1  19  13   2   2
# 0   7   7  18   5
#     D   A   C   B
# 3  19   9   5  16
# 2   6  13   0  19
# 4   5  17  16  11
# 1  19  13   2   2
# 0   7   7  18   5

# %%
#ordenar por columna
display(frame.sort_index(axis=1, ascending=False))
# Out:
#     D   C   B   A
# 3  19   5  16   9
# 2   6   0  19  13
# 4   5  16  11  17
# 1  19   2   2  13
# 0   7  18   5   7

# %%
# ordenar filas por valor en columna
display(frame.sort_values(by='A', ascending=True))
# Out:
#     D   A   C   B
# 0   7   7  18   5
# 3  19   9   5  16
# 2   6  13   0  19
# 1  19  13   2   2
# 4   5  17  16  11

# %%
# ordenar columnas por valor en fila
display(frame.sort_values(by=1, axis=1, ascending=True))
# Out:
#     C   B   A   D
# 3   5  16   9  19
# 2   0  19  13   6
# 4  16  11  17   5
# 1   2   2  13  19
# 0  18   5   7   7

# %%
# ordenar por valor en columna y guardar cambios
frame.sort_values(by='A', ascending=False, inplace=True)
display(frame)
# Out:
#     D   A   C   B
# 4   5  17  16  11
# 2   6  13   0  19
# 1  19  13   2   2
# 3  19   9   5  16
# 0   7   7  18   5

# %% [markdown]
# **Ranking**
# * Construir un ranking de valores

# %%
display(frame)
# Out:
#     D   A   C   B
# 4   5  17  16  11
# 2   6  13   0  19
# 1  19  13   2   2
# 3  19   9   5  16
# 0   7   7  18   5

# %%
display(frame.rank(method='max', axis=1))
# Out:
#      D    A    C    B
# 4  1.0  4.0  3.0  2.0
# 2  2.0  3.0  1.0  4.0
# 1  4.0  3.0  2.0  2.0
# 3  4.0  2.0  1.0  3.0
# 0  3.0  3.0  4.0  1.0

# %%
# Imprimir, uno a uno, los valores de la columna 'C' de mayor a menor
for x in frame.sort_values(by='C', ascending=False)['C'].values:
    print(x)
# Out:
# 18
# 16
# 5
# 2
# 0

# %% [markdown]
# ### Operaciones
# Operaciones matemáticas entre objetos

# %%
matrixA = np.random.randint(100,size=(4,4))
matrixB = np.random.randint(100,size=(4,4))
frameA = pd.DataFrame(matrixA)
frameB = pd.DataFrame(matrixB)
display(frameA)
display(frameB)
# Out:
#     0   1   2   3
# 0  16  35  17  38
# 1  95  47  13  17
# 2  39   5  76  32
# 3  80  98  21  70
#     0   1   2   3
# 0  44  81  64  21
# 1  34  43  57  35
# 2   6  23  79  30
# 3   9  43  37  72

# %%
# a través de métodos u operadores
display(frameA + frameB == frameA.add(frameB))
display(frameA + frameB)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#      0    1    2    3
# 0   60  116   81   59
# 1  129   90   70   52
# 2   45   28  155   62
# 3   89  141   58  142

# %%
display(frameB - frameA == frameB.sub(frameA))
display(frameB - frameA)
# Out:
#       0     1     2     3
# 0  True  True  True  True
# 1  True  True  True  True
# 2  True  True  True  True
# 3  True  True  True  True
#     0   1   2   3
# 0  28  46  47 -17
# 1 -61  -4  44  18
# 2 -33  18   3  -2
# 3 -71 -55  16   2

# %%
# si los frames no son iguales, valor por defecto NaN
frameC = pd.DataFrame(np.random.randint(100,size=(3,3)))
display(frameA)
display(frameC)
display(frameC + frameA)
# Out:
#     0   1   2   3
# 0  16  35  17  38
# 1  95  47  13  17
# 2  39   5  76  32
# 3  80  98  21  70
#     0   1   2
# 0  66  98  72
# 1  62  87  37
# 2  11  50  91
#        0      1      2   3
# 0   82.0  133.0   89.0 NaN
# 1  157.0  134.0   50.0 NaN
# 2   50.0   55.0  167.0 NaN
# 3    NaN    NaN    NaN NaN

# %%
# se puede especificar el valor por defecto con el argumento fill_value
display(frameA.add(frameC, fill_value=0))
# Out:
#        0      1      2     3
# 0   82.0  133.0   89.0  38.0
# 1  157.0  134.0   50.0  17.0
# 2   50.0   55.0  167.0  32.0
# 3   80.0   98.0   21.0  70.0

# %% [markdown]
# Operadores aritméticos solo válidos en elementos aceptables

# %%
import pandas as pd

# Cambia las letras por números
frameD = pd.DataFrame({0: [10, 20], 1: [30, 40]})

# Ahora la resta sí funcionará
resultado = frameD - 5
print(resultado)
# Out:
#     0   1
# 0   5  25
# 1  15  35

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
df = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(df)
display(df.iloc[0])
display(type(df.iloc[0]))
# uso común, averiguar la diferencia entre una fila y el resto
display(df - df.iloc[0])
display(df.sub(df.iloc[0], axis=1))
# Por columnas cómo se restaría
display(df.sub(df['A'], axis=0))
# Out:
#    A  B  C  D
# 0  2  6  1  7
# 1  0  6  3  2
# 2  4  9  0  2
# A    2
# B    6
# C    1
# D    7
# Name: 0, dtype: int32
# pandas.core.series.Series
#    A  B  C  D
# 0  0  0  0  0
# 1 -2  0  2 -5
# 2  2  3 -1 -5
#    A  B  C  D
# 0  0  0  0  0
# 1 -2  0  2 -5
# 2  2  3 -1 -5
#    A  B  C  D
# 0  0  4 -1  5
# 1  0  6  3  2
# 2  0  5 -4 -2

# %% [markdown]
# pandas se basa en NumPy, np operadores binarios y unarios son aceptables

# %% [markdown]
# ![image.png](attachment:454b1000-40f3-4dd4-a2e7-bc758c837fe9.png)

# %% [markdown]
# ![image.png](attachment:51d34371-144c-4097-8592-1db75550d7ed.png)

# %% [markdown]
# Aplicación de funciones a medida con lambda

# %%
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)
print(frame.apply(lambda x : x.max() - x.min(), axis = 1)) # diferencia por columnas
# Out:
#    A  B  C  D
# 0  6  8  7  0
# 1  7  5  6  9
# 2  0  2  0  2
# 0    8
# 1    4
# 2    2
# dtype: int64

# %%
def max_min(x):
    return x.max() - x.min()
print(frame.apply(max_min, axis = 0)) # diferencia por columna
# Out:
# A    7
# B    6
# C    7
# D    9
# dtype: int64

# %%
# diferencia entre min y max por fila (no columna)
rand_matrix = np.random.randint(10, size=(3, 4))
frame = pd.DataFrame(rand_matrix , columns=list('ABCD'))
display(frame)
print(frame.apply(lambda x : x.max() - x.min(), axis = 1)) # diferencia por fila
# Out:
#    A  B  C  D
# 0  5  0  1  8
# 1  9  5  9  3
# 2  5  7  7  6
# 0    8
# 1    6
# 2    2
# dtype: int64

# %% [markdown]
# ### Estadística descriptiva
# * Análisis preliminar de los datos
# * Para Series y DataFrame

# %% [markdown]
# ![image.png](attachment:d53c13e3-cf2c-4aa7-8848-37a129d2fcfd.png)

# %% [markdown]
# ![image.png](attachment:b6540e79-e3ac-423f-9b76-0713ac3c8e44.png)

# %%
diccionario = { 
    "nombre" : ["Marisa", "Laura", "Manuel", "Carlos"], 
    "edad" : [34, 30, 25, 40],  # <--- ¡Aquí faltaba el ] y quizás más números!
    "puntos" : [98, 12, 98, np.nan], 
    "genero": ["F", "F", "M", "M"] 
}

# %%
# operadores básicos
print(frame.sum())
display(frame)
print(frame.sum(axis=1, numeric_only=True))
# Out:
# A    19
# B    12
# C    17
# D    17
# dtype: int64
#    A  B  C  D
# 0  5  0  1  8
# 1  9  5  9  3
# 2  5  7  7  6
# 0    14
# 1    26
# 2    25
# dtype: int64

# %%
frame.mean(numeric_only=True)
# Out:
# A    6.333333
# B    4.000000
# C    5.666667
# D    5.666667
# dtype: float64

# %%
frame.cumsum()
# Out:
#     A   B   C   D
# 0   5   0   1   8
# 1  14   5  10  11
# 2  19  12  17  17

# %%
frame.count(axis=1)
# Out:
# 0    4
# 1    4
# 2    4
# dtype: int64

# %%
import pandas as pd
import numpy as np

# 1. Creamos el diccionario corregido (fíjate en los corchetes [ ])
diccionario = { 
    "nombre" : ["Marisa", "Laura", "Manuel", "Carlos"], 
    "edad"   : [34, 30, 25, 40], 
    "puntos" : [98, 12, 98, np.nan], 
    "genero" : ["F", "F", "M", "M"] 
}

# 2. Creamos el DataFrame
frame = pd.DataFrame(diccionario)

# 3. Mostramos los resultados
display(frame)
print("La desviación estándar de la edad es:")
print(frame['edad'].std())
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    30    12.0      F
# 2  Manuel    25    98.0      M
# 3  Carlos    40     NaN      M
# La desviación estándar de la edad es:
# 6.34428877022476

# %% [markdown]
# ### Agregaciones

# %%
display(frame)
df = frame.groupby('genero').count()
display(df)
# Out:
#    nombre  edad  puntos genero
# 0  Marisa    34    98.0      F
# 1   Laura    30    12.0      F
# 2  Manuel    25    98.0      M
# 3  Carlos    40     NaN      M
#         nombre  edad  puntos
# genero
# F            2     2       2
# M            2     2       1

# %%
# si es Nan descarta la fila
df = frame.groupby('puntos').count()
display(df)
# Out:
#         nombre  edad  genero
# puntos
# 12.0         1     1       1
# 98.0         2     2       2

# %%
display(frame.groupby('genero').mean(numeric_only=True))
# Out:
#         edad  puntos
# genero
# F       32.0    55.0
# M       32.5    98.0
