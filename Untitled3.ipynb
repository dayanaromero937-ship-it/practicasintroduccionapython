# %%
from PIL import Image
import matplotlib.pyplot as plt

# Ruta del archivo (ajústala si es necesario)
ruta = "Desktop/introduccionapythonpracticas/WhatsApp Image 2026-01-08 at 08.02.36 (1).jpeg"

img = Image.open(ruta)

plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       4 # Ruta del archivo (ajústala si es necesario)
#       5 ruta = "Desktop/introduccionapythonpracticas/WhatsApp Image 2026-01-08 at 08.02.36 (1).jpeg"
# ----> 7 img = Image.open(ruta)
#       9 plt.imshow(img)
#      10 plt.axis("off")
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop/introduccionapythonpracticas/WhatsApp Image 2026-01-08 at 08.02.36 (1).jpeg'
