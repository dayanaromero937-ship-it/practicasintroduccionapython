# %% [markdown]
# # TERCER MODULO - Ficheros
# # Autor: Elvis Pachacama [cite: 16]

# %% [markdown]
# ![logo](img/python_logo.png)

# %% [markdown]
# <img src="img/Recurso-26.png" width="200">
#
# ## TERCER MODULO - Ficheros
#
# ![logo](img/python_logo.png)
#
# *Elvis Pachacama*

# %% [markdown]
# http://localhost:8888/files/Desktop/introduccionapythonpracticas/WhatsApp%20Image%202026-02-02%20at%2010.21.35.jpeg?_xsrf=2%7C798382d4%7C1609031ff21ec0c1018f61f1acf1c4dc%7C1767828629
