# %%
# Out:
#   Cell In[2], line 1
#     blob:https://web.whatsapp.com/2e10daea-a60a-4c85-a803-3fe7b73ab742
#                                      ^
# SyntaxError: invalid decimal literal

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("nombre_de_la_imagen.jpg")
plt.imshow(img)
plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from PIL import Image
#       2 import matplotlib.pyplot as plt
# ----> 4 img = Image.open("nombre_de_la_imagen.jpg")
#       5 plt.imshow(img)
#       6 plt.axis("off")
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nombre_de_la_imagen.jpg'
